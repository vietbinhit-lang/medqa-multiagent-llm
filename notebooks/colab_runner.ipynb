# %% [markdown]
# # MedQA Multi-Agent LLM - Colab Runner
#
# This notebook only clones the repo and runs the code that lives there - it does not contain pipeline logic itself, so everything stays reproducible from GitHub.

# %%
# !git clone https://github.com/vietbinhit-lang/medqa-multiagent-llm.git
# %cd medqa-multiagent-llm
# !pip install -q -r requirements.txt

# %% [markdown]
# ## Serve the local LLM (vLLM)
#
# Run this cell, wait for the server to be ready, then run evaluation in the next cell.

# %%
# !pip install -q vllm
get_ipython().system_raw('python -m vllm.entrypoints.openai.api_server --model Qwen/Qwen2.5-7B-Instruct --port 8000 &')

# %%
# !python eval/run_eval.py --config configs/v0_baseline.yaml
